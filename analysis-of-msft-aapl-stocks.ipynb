# %% [markdown]
# # **Stock Analysis of (AAPL,MSFT)**

# %% [markdown]
# <img src="https://9to5mac.com/wp-content/uploads/sites/6/2021/10/apple-microsoft-stock-price.jpg?quality=82&strip=all" width="800">

# %% [markdown]
# ## Here we have  3 stocks and we will perform all the possible operations so we can understand nature of  stock

# %%
# Importing the lib. for Various operations on Data
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#use read_csv for  raeding the data in our notebook and set the index is date
df=pd.read_csv("/kaggle/input/hhhhhhhh/FDA_UnivariateBasicNumericDescStats_Dataset (1).csv",usecols=['Open_AAPL', 'High_AAPL', 'Low_AAPL', 'Close_AAPL', 'Volume-AAPL',
       'AdjClose_AAPL', 'DailyLogRetAAPL','Open_MSFT', 'High_MSFT', 'Low_MSFT', 'Close_MSFT', 'Volume_MSFT',
       'AdjClose_MSFT', 'DailyLogRetMSFT'])

# %%
# see the information of the file and data what is store in this csv file 
df
# Out:
#       Open_AAPL  High_AAPL  Low_AAPL  Close_AAPL  Volume-AAPL  AdjClose_AAPL  \
# 0        104.87     112.50    101.69      111.94     19144400          27.87
# 1        108.25     110.62    101.19      102.50     18310000          25.52
# 2        103.75     110.56    103.00      104.00     27818000          25.89
# 3        106.12     107.00     95.00       95.00     27443200          23.65
# 4         96.50     101.00     95.50       99.50     16463200          24.77
# ...         ...        ...       ...         ...          ...            ...
# 1503      74.17      74.26     73.30       73.35      8209200          73.04
# 1504      74.00      75.18     73.95       74.23     21092500          73.91
# 1505      74.47      74.76     73.32       73.57     14218400          73.26
# 1506      73.78      73.82     71.42       71.45     17500900          71.14
# 1507      70.91      72.43     70.34       71.89     22295100          71.58
#
# ...

# %%
#check the columns how many columns in the csv file and the  name of the coulmns
df.columns
# Out:
# Index(['Open_AAPL', 'High_AAPL', 'Low_AAPL', 'Close_AAPL', 'Volume-AAPL',
#        'AdjClose_AAPL', 'DailyLogRetAAPL', 'Open_MSFT', 'High_MSFT',
#        'Low_MSFT', 'Close_MSFT', 'Volume_MSFT', 'AdjClose_MSFT',
#        'DailyLogRetMSFT'],
#       dtype='object')

# %%
# then check the info of the fetures what they have and the type of the data 
# also we have  the concpet of null values so here no any null values in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open_AAPL        1508 non-null   float64
#  1   High_AAPL        1508 non-null   float64
#  2   Low_AAPL         1508 non-null   float64
#  3   Close_AAPL       1508 non-null   float64
#  4   Volume-AAPL      1508 non-null   int64
#  5   AdjClose_AAPL    1508 non-null   float64
#  6   DailyLogRetAAPL  1508 non-null   float64
#  7   Open_MSFT        1508 non-null   float64
#  8   High_MSFT        1508 non-null   float64
#  9   Low_MSFT         1508 non-null   float64
#  10  Close_MSFT       1508 non-null   float64
#  11  Volume_MSFT      1508 non-null   int64
#  12  AdjClose_MSFT    1508 non-null   float64
#  13  DailyLogRetMSFT  1508 non-null   float64
# dtypes: float64(12), int64(2)
# memory usage: 165.1 KB

# %%
# now we will check the sample of the data what type of data store with the help of df.sample
df.sample(10)
# Out:
#       Open_AAPL  High_AAPL  Low_AAPL  Close_AAPL  Volume-AAPL  AdjClose_AAPL  \
# 809       14.55      14.56     14.30       14.41      6369400           7.17
# 1497      72.68      72.86     71.35       72.18     20041500          71.87
# 1234      67.79      67.95     66.27       67.79     28591200          33.75
# 814       14.36      14.69     14.27       14.60      6120400           7.27
# 1261      69.83      70.70     67.88       68.96     61618200          34.33
# 1086      26.71      26.96     25.49       25.78     16660800          12.83
# 884       20.01      20.40     19.87       19.90      6728800           9.91
# 1444      52.33      53.65     51.88       53.61     18986900          53.38
# 1313      42.75      42.96     42.47       42.53      9836100          42.35
# 491       20.89      21.33     20.22       21.01      8401400          10.46
#
#       DailyLogRetAAPL  Open_MSFT  High_MSFT  Low_MSFT  Close_MSFT  \
# ...

# %%
# now the time is describe of the data so we can identify what is mean std max min all the possible operation 
# we can identify outliers also with the help of min max mean 75% and 25% percentile
df[['Open_AAPL', 'High_AAPL', 'Low_AAPL', 'Close_AAPL', 'Volume-AAPL',
       'AdjClose_AAPL', 'DailyLogRetAAPL']].describe()
# Out:
#          Open_AAPL    High_AAPL     Low_AAPL   Close_AAPL   Volume-AAPL  \
# count  1508.000000  1508.000000  1508.000000  1508.000000  1.508000e+03
# mean     36.284251    37.120524    35.486598    36.306048  1.580790e+07
# std      27.289441    28.111887    26.507658    27.287054  1.348305e+07
# min      12.990000    13.190000    12.720000    13.120000  1.405000e+06
# 25%      19.095000    19.560000    18.605000    19.085000  8.692450e+06
# 50%      23.635000    24.195000    23.100000    23.705000  1.227730e+07
# 75%      44.745000    45.820000    44.167500    45.560000  1.792290e+07
# max     142.440000   150.380000   140.000000   144.190000  2.650690e+08
#
#        AdjClose_AAPL  DailyLogRetAAPL
# count    1508.000000      1508.000000
# mean       19.315968         0.000603
# std        14.656912         0.037359
# min         6.530000        -0.730000
# 25%         9.497500        -0.020000
# 50%        11.800000         0.000000
# 75%        27.477500         0.020000
# ...

# %%
# again check the null value for every coilumns  with the help of .isnull() function
df.isnull().sum()
# Out:
# Open_AAPL          0
# High_AAPL          0
# Low_AAPL           0
# Close_AAPL         0
# Volume-AAPL        0
# AdjClose_AAPL      0
# DailyLogRetAAPL    0
# Open_MSFT          0
# High_MSFT          0
# Low_MSFT           0
# Close_MSFT         0
# Volume_MSFT        0
# AdjClose_MSFT      0
# DailyLogRetMSFT    0
# dtype: int64

# %%
# now we calculate the q1 and q2 of MSFT and AAPL for IQR so we can better understand of share movment

# IQR for MSFT
q1=np.nanpercentile(df["DailyLogRetMSFT"],25)
q2=np.nanpercentile(df["DailyLogRetMSFT"],75)
IQR_MSFT=q2-q1


# IQR for AAPL 
q1=np.nanpercentile(df["DailyLogRetAAPL"],25)
q2=np.nanpercentile(df["DailyLogRetAAPL"],75)
IQR_AAPL=q2-q1

# %% [markdown]
# ##  So here IQR of AAPL is higher means its Volatile risk (prices fluctuate rapidly)
# <img src="https://m.economictimes.com/thumb/msid-75804563,width-1200,height-900,resizemode-4,imgsize-52501/market-risk-1-getty.jpg" width="400">

# %%
import seaborn as sns
from scipy import stats
sns.set(rc={'figure.figsize':(14,5)})
sns.distplot(df['DailyLogRetAAPL'], kde=False, fit=stats.norm,color="g")
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='DailyLogRetAAPL'>

# %%
import seaborn as sns
from scipy import stats
sns.set(rc={'figure.figsize':(14,5)})
sns.distplot(df['DailyLogRetMSFT'], kde=False, fit=stats.norm,color="y")
# Out:
# <AxesSubplot:xlabel='DailyLogRetMSFT'>

# %%
df1=['Open_AAPL', 'High_AAPL', 'Low_AAPL', 'Close_AAPL', 'Volume-AAPL',
       'AdjClose_AAPL', 'DailyLogRetAAPL']

# %%
plt.figure(figsize=(17,7), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of mtcars', fontsize=20)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
print(IQR_MSFT)
print(IQR_AAPL)
# Out:
# 0.02
# 0.04

# %%
df["DailyLogRetMSFT"].skew()
# Out:
# -0.21643527021480816

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create a DataFrame from a CSV file

# Define the data and the target
X = df[['Close_AAPL']]
y = df['Open_AAPL']

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Plot the data points
plt.scatter(X, y)

# Plot the regression line
plt.plot(X, model.predict(X), color='r')

# Label the axes
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*WtZDnrVjk4sPoNc4Br1Hvw.jpeg" width="600">

# %%
#A candlestick chart is a handy tool to analyze the price movements of stock prices. 
# Here’s how you can visualize a candlestick chart of Apple Stock:
from datetime import date, timedelta
import plotly.graph_objects as go
import plotly.express as px
figure = go.Figure(data=[go.Candlestick(x=df.index,
                                        open=df["Open_AAPL"], high=df["High_AAPL"],
                                        low=df["Low_AAPL"], close=df["Close_AAPL"])])
figure.update_layout(title = " Stock Price Analysis", xaxis_rangeslider_visible=False)
figure.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
# here we can see the line graph the prices fluctation in MSFT is high 
df.Close_AAPL.plot(figsize=(17,8),label='Close AAPL')
df.Close_MSFT.plot(figsize=(17,8),label='Close MSFT')
plt.title("Close Price of MSFT and AAPL")
plt.legend()

# %%
# A closer look at the 20-days rolling standard deviation will make everything clear.
plt.plot(df['Close_AAPL'].rolling(20).std())
plt.xlabel("Time")
plt.ylabel("20-days rolling standard deviation")
plt.rcParams['figure.figsize'] = [17, 6]
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split


# split the data into training and testing sets
train_data, test_data, train_target, test_target = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2)

# train a support vector regression (SVR) model
model = SVR()
model.fit(train_data, train_target)

# make predictions using the test set
predictions = model.predict(test_data)

# calculate mean squared error
mse = np.mean((predictions - test_target)**2)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.0016892668851293817

# %% [markdown]
# ## It’s clear that it’s not a constant value, but it has spikes and oscillations. The fat tails of the distribution may be caused by these volatility spikes, which create non-neglectable outliers.

# %% [markdown]
# ## SUMMARY of Analysis
# ### ( this analysis only for practies not for any suggestions).
#
#
# ### Here the stock of Apple is not stable and very risk to tread in this share.
# ### Microsoft share is  stable so we can take risk for investing on this share because its not fluctuate rapidly.
